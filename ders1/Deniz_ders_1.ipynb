# %%
print("Hello World")
# Out:
# Hello World

# %%
#yorum

'''

 uzun yorum satırı 


'''
# Out:
# '\n\n uzun yorum satırı \n\n\n'

# %%
int
float
str

# %%
# tanımlanan değişken harf ile başlamalı ve uygun karakterler kullanılmalı
a=5
type(a)
# Out:
# int

# %%
a=5.2
type(a)
# Out:
# float

# %%
a=5
a,d=2,3
print(a+d)
# 2 değişken aynı anda tanımlanabilir
# Out:
# 5

# %%
a=5.3
a=int(a)
print(a)
# Out:
# 5

# %%
a=2+3
b=5-4
c=3^2
d=3**2
e=5//3
f=7%2
print(a,b,c,d,e,f)
# Out:
# 5 1 1 9 1 1

# %%
a="abc"
s=4
d=str(s)
print(d)
print(type(d))
# Out:
# 4
# <class 'str'>
# aaaa

# %%
a = "a"*4
print(a)

# %%
a="abc"
s="ddd"
x="ssss"
print(a+s+x)
# Out:
# abcdddssss

# %%
a="Deniz Nazari"
# Python'da işlemler 0'dan başlıyor, 0. eleman {D}, 1. eleman {e}...
# d=a[:6]
# d=a[1]
# d=a[:]
# d=a[-1]
# d=a[::2]
print(d)

# %%
a=bool(0)
b=bool(5)
c=bool("qq")
print(a,b,c)
# Out:
# False True True

# %%
a="x"
b=int(a)
print(b)
# Hata verir çünkü x sayı değeri taşımıyor
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-17b92380978a> in <module>
#       1 a="x"
# ----> 2 b=int(a)
#       3 print(b)
#       4 # Hata verir çünkü x sayı değeri taşımıyor
#
# ValueError: invalid literal for int() with base 10: 'x'

# %%
a=int(input("en küçük doğal sayı kaçtır ?"))
print(type(a))
# Out:
# isminiz ? 5
# <class 'int'>

# %%
a=input("isminiz ? ")
print("Benim ismim {}".format(a))
print(f"Benim ismim {a}")
print(f"Benim ismim "+a)
# Out:
# isminiz ? Deniz
# Benim ismim Deniz
# Benim ismim Deniz
# Benim ismim Deniz

# %%
# Uygulama 1: Bir öğrencinin aşağıdaki bilgileri için gerekli değişkenleri oluşturunuz
ad = input("İsminiz : ")
sad = input("Soyisminiz : ")
num = input("Numaranız : ")
g = input("Cinsiyetiniz : ")
tc = int(input("TC kimlik numaranız : "))
dyil = input("Doğum yılınız : ")
yas = input("Yaşınız : ")
print(f"""{ad} {sad} adlı {num} numaralı öğrencimizin cinsiyeti {g} olup {tc} kimlik numarasına sahiptir.
{dyil} yılında doğmuş olup {yas} yaşındadır.
""")
# Out:
# İsminiz : Ömer
# Soyisminiz : Gavalcı
# Numaranız : 82162022
# Cinsiyetiniz : erkek
# TC kimlik numaranız : 507913308
# Doğum yılınız : 2001
# Yaşınız : 21
# Ömer Gavalcı adlı 82162022 numaralı öğrencimizin cinsiyeti erkek olup 507913308 kimlik numarasına sahiptir.
# 2001 yılında doğmuş olup 21 yaşındadır.

# %%
print("Deniz","Nazari",sep=" ")
# sep komutu her bir terimin arasına
print("Deniz","Nazari","15","8",sep="___")
# Out:
# Deniz Nazari
# Deniz___Nazari___15___8

# %%
isim = "Deniz"
soyisim = "Nazari"
print("Benim ismim {} {}".format(isim,soyisim))
print("Benim ismim {0} {1}".format(isim,soyisim))
print("Benim ismim {d} {k}".format(d=isim,k=soyisim))
print("benim yasim: {:1.3}".format(3.459))
# Out:
# Benim ismim Deniz Nazari
# Benim ismim Deniz Nazari
# Benim ismim Deniz Nazari

# %%
a="Merhaba Dünya"
z=a.upper()
print(z)
k=a.lower()
print(k)
# Out:
# MERHABA DÜNYA
# merhaba dünya

# %%
d=input("isminiz : ").lower()
print(d)
f=input("isminiz : ").title()
print(f)
# Out:
# isminiz : ADNAN
# adnan
# isminiz : adnan
# Adnan

# %%
d=input("İsminiz : ").islower()
print(d)
# Out:
# isminiz : Ömer
# False

# %%
isim=["ahmetharun","deniznazari","baran"]
print(len(isim[0]))
print(len(isim[1]))
print(len(isim[2]))
print(len(isim))
print(isim[:2])
print(isim[0][0])
print(isim[1][-1])
# Out:
# 10
# 11
# 5
# 3
# ['ahmetharun', 'deniznazari']
# a
# i

# %%
a= ",matbil,bilgisayar,,istatistik,tıp".split(",")
print(a)
print("  ".join(a))
# Out:
# ['', 'matbil', 'bilgisayar', '', 'istatistik', 'tıp']
#   matbil  bilgisayar    istatistik  tıp

# %%
f= ",matbil,bilgisayar,,istatistik,tıp"
a= len("bilgisayar")
d = f.index("bilgisayar")
print(d)
print(f[d:d+a])
# Out:
# 8
# bilgisayar

# %%
a = input("İsminiz : ")
print(a.startswith("d"))
b = "Ben matematiği seviyorum"
s1 = b.replace(" ","_")
s2 = b.replace("m","_")
s3 = b.replace("ma","_")
print(s1,s2,s3)
# Out:
# İsminiz : Deniz
# False
# Ben_matematiği_seviyorum Ben _ate_atiği seviyoru_ Ben _te_tiği seviyorum

# %%
a=input("Yaşınız ? ").isdigit()
print(a)
b=input("Yaşınız ? ").isalpha()
print(b)
# Out:
# Yaşınız ? 123
# True
# Yaşınız ? 123
# False

# %%
a="www.matbil.com"
z=a.lstrip("w.")
z=z.rstrip(".com")
print(z)
# Out:
# matbil

# %%
a="www.matbil.com"
z=a.count("w",0,4)
print(z)
# Out:
# 3

# %%
a="Deniz"
z=a.center(20,"-")
print(z)
